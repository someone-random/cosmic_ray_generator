# %%
from rejection_sampler import generator
import matplotlib.pyplot as plt

# %%
testgen=generator()

# %%
a=testgen.create(n=100)

# %%
plt.scatter([a[i][0] for i in range(len(a))],[a[i][1] for i in range(len(a))])

# %%
x
# Out:
# [1.6933437041698198,
#  6.411375058256226,
#  7.421945911201533,
#  1.5166973434853617,
#  1.1647118107209735,
#  1.5860351957473995,
#  3.5281360451600676,
#  3.50975060840085,
#  4.201487535477554,
#  0.3929065667258391,
#  4.907187975225838,
#  5.696473904244613,
#  1.1161934386659595,
#  1.1308355741572313,
#  33.46198797464183,
#  1.8782661298922676,
#  2.052906212059952,
#  0.7698016843793312,
#  0.8082602476654301,
#  1.5348423120819916,
#  0.8725955562310901,
#  0.44188955529618335,
#  0.5102029752537192,
#  0.5714153360721639,
#  2.5051461973852156,
#  0.4682103588100972,
#  1.1161599130115292,
#  10.560547762321676,
#  1.0828487641989568,
#  0.46132454102614806,
#  0.5289877894855408,
#  3.031725831926792,
#  1.5114112902696206,
#  0.9357314059235478,
#  0.8687964067023586,
#  0.7422918583131377,
#  1.2890203778880505,
#  1.2139628486276024,
#  5.37800731741288,
#  2.482537636279062,
#  2.2259895425248715,
#  2.457401523857243,
#  6.897673696592619,
#  2.0625478456904602,
# ...
